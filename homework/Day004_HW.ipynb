# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# ### r.text 將每一筆資料單純讀取
# ### json將每一筆資料的標頭都額外分好 像是清單一樣

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"10966253069","type":"PushEvent","actor":{"id":25290312,"login":"vchoudhari45","display_login":"vchoudhari45","gravatar_id":"","url":"https://api.github.com/users/vchoudhari45","avatar_url":"https://avatars.githubusercontent.com/u/25290312?"},"repo":{"id":155360411,"name":"vchoudhari45/leetcode","url":"https://api.github.com/repos/vchoudhari45/leetcode"},"payload":{"push_id":4330559492,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"44f68bc7699ca3736bcae346cfc0b284dd206b45","before":"5e15b5c7f032f43779ab24a5545f131ade5afdb4","commits":[{"sha":"44f68bc7699ca3736bcae346cfc0b284dd206b45","author":{"email":"vishal.choudhari2011@gmail.com","name":"Vishal Choudhari"},"message":"L480","distinct":true,"url":"https://api.github.com/repos/vchoudhari45/leetcode/commits/44f68bc7699ca3736bcae346cfc0b284dd206b45"}]},"public":true,"created_at":"2019-11-28T06:24:19Z"},{"id":"10966253070","type":"CreateEvent","actor":{"id":13423,"login":"nurse","display_login":"nurse","gravatar_id":"","url":"https://api.github.com/users/nurse","avatar_url":"https://avatars.githubusercontent.com/u/13423?"},"repo":{"id":2888246,"name":"ruby/rubyci","url":"https://api.github.com/repos/ruby/rubyci"},"payload":{"ref":"format-sponsors-as-list","ref_type":"branch","master_branch":"master","description":"The Ruby CI for chkbuild","pusher_type":"user"},"public":true,"created_at":"2019-11-28T06:24:19Z","org":{"id":210414,"login":"ruby","gravatar_id":"","url":"https://api.github.com/orgs/ruby","avatar_url":"https://avatars.githubusercontent.com/u/210414?"}},{"id":"10966253061","type":"DeleteEvent","actor":{"id":27856297,"login":"dependabot-preview[bot]","display_login":"dependabot-preview","gravatar_id":"","url":"https://api.github.com/users/dependabot-preview[bot]","avatar_url":"https://avatars.githubusercontent.com/u/27856297?"},"repo":{"id":193245006,"name":"PasteUs/PasteMeFrontend","url":"https://api.github.com/repos/PasteUs/PasteMeFrontend"},"payload":{"ref":"dependabot/npm_and_yarn/dev/core-js-3.4.4","ref_type":"branch","pusher_type":"user"},"public":true,"created_at":"2019-11-28T06:24:19Z","org":{"id":54676094,"login":"PasteUs","gravatar_id":"","url":"https://api.github.com/orgs/PasteUs","avatar_url":"https://avatars.githubusercontent.com/u/54676094?"}},{"id":"10966253063","type":"WatchEvent","actor":{"id":87781,"login":"TheAncientGoat","display_login":"TheAncientGoat","gravatar_id":"","url":"https://api.github.com/users/TheAncientGoat","avatar_url":"https://avatars.githubusercontent.com/u/87781?"},"repo":{"id":197923333,"name":"Quramy/typescript-eslint-language-service","url":"https://api.github.com/repos/Quramy/typescript-eslint-language-service"},"payload":{"action":"started"},"public":true,"created_at":"2019-11-28T06:24:19Z"},{"id":"10966253051","type":"DeleteEvent","actor":{"id":29139614,"login":"renovate[bot]","display_login":"renovate","gravatar_id":"","url":"https://api.github.com/users/renovate[bot]","avatar_url":"https://avatars.githubusercontent.com/u/29139614?"},"repo":{"id":203676326,"name":"ng-qt/ng-qt","url":"https://api.github.com/repos/ng-qt/ng-qt"},"payload":{"ref":"renovate/ts-node-8.x","ref_type":"branch","pusher_type":"user"},"public":true,"created_at":"2019-11-28T06:24:19Z","org":{"id":54956949,"login":"ng-qt","gravatar_id":"","url":"https://api.github.com/orgs/ng-qt","avatar_url":"https://avatars.githubusercontent.com/u/54956949?"}},{"id":"10966253038","type":"IssueCommentEvent","actor":{"id":42455533,"login":"taos-ci","display_login":"taos-ci","gravatar_id":"","url":"https://api.github.com/users/taos-ci","avatar_url":"https://avatars.githubusercontent.com/u/42455533?"},"repo":{"id":141988388,"name":"nnsuite/nnstreamer","url":"https://api.github.com/repos/nnsuite/nnstreamer"},"payload":{"action":"created","issue":{"url":"https://api.github.com/repos/nnsuite/nnstreamer/issues/1898","repository_url":"https://api.github.com/repos/nnsuite/nnstreamer","labels_url":"https://api.github.com/repos/nnsuite/nnstreamer/issues/1898/l ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '10966253069',
#   'type': 'PushEvent',
#   'actor': {'id': 25290312,
#    'login': 'vchoudhari45',
#    'display_login': 'vchoudhari45',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/vchoudhari45',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25290312?'},
#   'repo': {'id': 155360411,
#    'name': 'vchoudhari45/leetcode',
#    'url': 'https://api.github.com/repos/vchoudhari45/leetcode'},
#   'payload': {'push_id': 4330559492,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '44f68bc7699ca3736bcae346cfc0b284dd206b45',
#    'before': '5e15b5c7f032f43779ab24a5545f131ade5afdb4',
#    'commits': [{'sha': '44f68bc7699ca3736bcae346cfc0b284dd206b45',
#      'author': {'email': 'vishal.choudhari2011@gmail.com',
#       'name': 'Vishal Choudhari'},
#      'message': 'L480',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/vchoudhari45/leetcode/commits/44f68bc7699ca3736bcae346cfc0b284dd206b45'}]},
#   'public': True,
#   'created_at': '2019-11-28T06:24:19Z'},
#  {'id': '10966253070',
#   'type': 'CreateEvent',
#   'actor': {'id': 13423,
#    'login': 'nurse',
#    'display_login': 'nurse',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nurse',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13423?'},
#   'repo': {'id': 2888246,
#    'name': 'ruby/rubyci',
#    'url': 'https://api.github.com/repos/ruby/rubyci'},
#   'payload': {'ref': 'format-sponsors-as-list',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'The Ruby CI for chkbuild',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-11-28T06:24:19Z',
#   'org': {'id': 210414,
#    'login': 'ruby',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/ruby',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/210414?'}},
#  {'id': '10966253061',
#   'type': 'DeleteEvent',
#   'actor': {'id': 27856297,
#    'login': 'dependabot-preview[bot]',
#    'display_login': 'dependabot-preview',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot-preview[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27856297?'},
#   'repo': {'id': 193245006,
#    'name': 'PasteUs/PasteMeFrontend',
#    'url': 'https://api.github.com/repos/PasteUs/PasteMeFrontend'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/dev/core-js-3.4.4',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-11-28T06:24:19Z',
#   'org': {'id': 54676094,
#    'login': 'PasteUs',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/PasteUs',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54676094?'}},
#  {'id': '10966253063',
#   'type': 'WatchEvent',
#   'actor': {'id': 87781,
#    'login': 'TheAncientGoat',
#    'display_login': 'TheAncientGoat',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/TheAncientGoat',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/87781?'},
#   'repo': {'id': 197923333,
#    'name': 'Quramy/typescript-eslint-language-service',
#    'url': 'https://api.github.com/repos/Quramy/typescript-eslint-language-service'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2019-11-28T06:24:19Z'},
#  {'id': '10966253051',
#   'type': 'DeleteEvent',
#   'actor': {'id': 29139614,
#    'login': 'renovate[bot]',
#    'display_login': 'renovate',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/renovate[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29139614?'},
#   'repo': {'id': 203676326,
#    'name': 'ng-qt/ng-qt',
#    'url': 'https://api.github.com/repos/ng-qt/ng-qt'},
#   'payload': {'ref': 'renovate/ts-node-8.x',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-11-28T06:24:19Z',
#   'org': {'id': 54956949,
#    'login': 'ng-qt',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/ng-qt',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54956949?'}},
#  {'id': '10966253038',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 42455533,
#    'login': 'taos-ci',
#    'display_login': 'taos-ci',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/taos-ci',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/42455533?'},
#   'repo': {'id': 141988388,
#    'name': 'nnsuite/nnstreamer',
#    'url': 'https://api.github.com/repos/nnsuite/nnstreamer'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/nnsuite/nnstreamer/issues/1898',
#     'repository_url': 'https://api.github.com/repos/nnsuite/nnstreamer',
#     'labels_url': 'https://api.github.com/repos/nnsuite/nnstreamer/issues/1898/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/nnsuite/nnstreamer/issues/1898/comments',
#     'events_url': 'https://api.github.com/repos/nnsuite/nnstreamer/issues/1898/events',
#     'html_url': 'https://github.com/nnsuite/nnstreamer/pull/1898',
#     'id': 529710788,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQ2NTM1NjIz',
#     'number': 1898,
#     'title': '[Doc] dimension in converter @open sesame 11/28 15:24',
#     'user': {'login': 'jaeyun-jung',
#      'id': 39614140,
#      'node_id': 'MDQ6VXNlcjM5NjE0MTQw',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/39614140?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/jaeyun-jung',
#      'html_url': 'https://github.com/jaeyun-jung',
#      'followers_url': 'https://api.github.com/users/jaeyun-jung/followers',
#      'following_url': 'https://api.github.com/users/jaeyun-jung/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/jaeyun-jung/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/jaeyun-jung/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/jaeyun-jung/subscriptions',
#      'organizations_url': 'https://api.github.com/users/jaeyun-jung/orgs',
#      'repos_url': 'https://api.github.com/users/jaeyun-jung/repos',
#      'events_url': 'https://api.github.com/users/jaeyun-jung/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/jaeyun-jung/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 4,
#     'created_at': '2019-11-28T06:02:52Z',
#     'updated_at': '2019-11-28T06:24:19Z',
#     'closed_at': None,
#     'author_association': 'COLLABORATOR',
#     'pull_request': {'url': 'https://api.github.com/repos/nnsuite/nnstreamer/pulls/1898',
#      'html_url': 'https://github.com/nnsuite/nnstreamer/pull/1898',
#      'diff_url': 'https://github.com/nnsuite/nnstreamer/pull/1898.diff',
#      'patch_url': 'https://github.com/nnsuite/nnstreamer/pull/1898.patch'},
#     'body': 'update docs about the dimension of each media stream.\r\n\r\nSigned-off-by: Jaeyun Jung <jy1210.jung@samsung.com>\r\n'},
#    'comment': {'url': 'https://api.github.com/repos/nnsuite/nnstreamer/issues/comments/559359213',
#     'html_url': 'https://github.com/nnsuite/nnstreamer/pull/1898#issuecomment-559359213',
#     'issue_url': 'https://api.github.com/repos/nnsuite/nnstreamer/issues/1898',
#     'id': 559359213,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU1OTM1OTIxMw==',
#     'user': {'login': 'taos-ci',
#      'id': 42455533,
#      'node_id': 'MDQ6VXNlcjQyNDU1NTMz',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/42455533?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/taos-ci',
#      'html_url': 'https://github.com/taos-ci',
#      'followers_url': 'https://api.github.com/users/taos-ci/followers',
#      'following_url': 'https://api.github.com/users/taos-ci/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/taos-ci/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/taos-ci/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/taos-ci/subscriptions',
#      'organizations_url': 'https://api.github.com/users/taos-ci/orgs',
#      'repos_url': 'https://api.github.com/users/taos-ci/repos',
#      'events_url': 'https://api.github.com/users/taos-ci/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/taos-ci/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2019-11-28T06:24:19Z',
#     'updated_at': '2019-11-28T06:24:19Z',
#     'author_association': 'COLLABORATOR',
#     'body': '**INFO:** You can read if there are misspelled characters at our misspelling check report. Please read http://nnsuite.mooo.com/nnstreamer/ci/repo-workers/pr-checker/1898-201911281524090.051371097564697-67f98019d5904e12ed9180a3c400aa1d0c7cde40/report/misspelling_result.txt.'}},
#   'public': True,
#   'created_at': '2019-11-28T06:24:19Z',
#   'org': {'id': 40420229,
#    'login': 'nnsuite',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/nnsuite',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/40420229?'}},
#  {'id': '10966253026',
#   'type': 'WatchEvent',
#   'actor': {'id': 25289725,
#    'login': 'jitingcn',
#    'display_login': 'jitingcn',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jitingcn',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25289725?'},
#   'repo': {'id': 197710783,
#    'name': 'miyouzi/akamTester',
#    'url': 'https://api.github.com/repos/miyouzi/akamTester'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2019-11-28T06:24:19Z'},
#  {'id': '10966253023',
#   'type': 'WatchEvent',
#   'actor': {'id': 48675940,
#    'login': 'RNADz',
#    'display_login': 'RNADz',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/RNADz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/48675940?'},
#   'repo': {'id': 1424470,
#    'name': 'moment/moment',
#    'url': 'https://api.github.com/repos/moment/moment'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2019-11-28T06:24:19Z',
#   'org': {'id': 4129662,
#    'login': 'moment',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/moment',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4129662?'}},
#  {'id': '10966253021',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 6912859,
#    'login': 'mikhailOK',
#    'display_login': 'mikhailOK',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mikhailOK',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6912859?'},
#   'repo': {'id': 151331938,
#    'name': 'nearprotocol/nearcore',
#    'url': 'https://api.github.com/repos/nearprotocol/nearcore'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/nearprotocol/nearcore/issues/1792',
#     'repository_url': 'https://api.github.com/repos/nearprotocol/nearcore',
#     'labels_url': 'https://api.github.com/repos/nearprotocol/nearcore/issues/1792/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/nearprotocol/nearcore/issues/1792/comments',
#     'events_url': 'https://api.github.com/repos/nearprotocol/nearcore/issues/1792/events',
#     'html_url': 'https://github.com/nearprotocol/nearcore/pull/1792',
#     'id': 529653861,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQ2NDkwNjY4',
#     'number': 1792,
#     'title': 'Bounded state parts',
#     'user': {'login': 'mikhailOK',
#      'id': 6912859,
#      'node_id': 'MDQ6VXNlcjY5MTI4NTk=',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/6912859?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/mikhailOK',
#      'html_url': 'https://github.com/mikhailOK',
#      'followers_url': 'https://api.github.com/users/mikhailOK/followers',
#      'following_url': 'https://api.github.com/users/mikhailOK/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/mikhailOK/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/mikhailOK/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/mikhailOK/subscriptions',
#      'organizations_url': 'https://api.github.com/users/mikhailOK/orgs',
#      'repos_url': 'https://api.github.com/users/mikhailOK/repos',
#      'events_url': 'https://api.github.com/users/mikhailOK/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/mikhailOK/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 5,
#     'created_at': '2019-11-28T02:09:13Z',
#     'updated_at': '2019-11-28T06:24:19Z',
#     'closed_at': None,
#     'author_association': 'COLLABORATOR',
#     'pull_request': {'url': 'https://api.github.com/repos/nearprotocol/nearcore/pulls/1792',
#      'html_url': 'https://github.com/nearprotocol/nearcore/pull/1792',
#      'diff_url': 'https://github.com/nearprotocol/nearcore/pull/1792.diff',
#      'patch_url': 'https://github.com/nearprotocol/nearcore/pull/1792.patch'},
#     'body': 'Improve state parts splitting logic: now we can have an upper bound\r\non a state part overhead that depends on max key length and max value\r\nlength.'},
#    'comment': {'url': 'https://api.github.com/repos/nearprotocol/nearcore/issues/comments/559359212',
#     'html_url': 'https://github.com/nearprotocol/nearcore/pull/1792#issuecomment-559359212',
#     'issue_url': 'https://api.github.com/repos/nearprotocol/nearcore/issues/1792',
#     'id': 559359212,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU1OTM1OTIxMg==',
#     'user': {'login': 'mikhailOK',
#      'id': 6912859,
#      'node_id': 'MDQ6VXNlcjY5MTI4NTk=',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/6912859?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/mikhailOK',
#      'html_url': 'https://github.com/mikhailOK',
#      'followers_url': 'https://api.github.com/users/mikhailOK/followers',
#      'following_url': 'https://api.github.com/users/mikhailOK/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/mikhailOK/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/mikhailOK/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/mikhailOK/subscriptions',
#      'organizations_url': 'https://api.github.com/users/mikhailOK/orgs',
#      'repos_url': 'https://api.github.com/users/mikhailOK/repos',
#      'events_url': 'https://api.github.com/users/mikhailOK/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/mikhailOK/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2019-11-28T06:24:19Z',
#     'updated_at': '2019-11-28T06:24:19Z',
#     'author_association': 'COLLABORATOR',
#     'body': 'Right now they are unlimited, they should be limited by our config.'}},
#   'public': True,
#   'created_at': '2019-11-28T06:24:19Z',
#   'org': {'id': 42587064,
#    'login': 'nearprotocol',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/nearprotocol',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/42587064?'}},
#  {'id': '10966253018',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 16239342,
#    'login': 'pyup-bot',
#    'display_login': 'pyup-bot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pyup-bot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16239342?'},
#   'repo': {'id': 52478119,
#    'name': 'rutsky/setuptools-trial',
#    'url': 'https://api.github.com/repos/rutsky/setuptools-trial'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/rutsky/setuptools-trial/issues/118',
#     'repository_url': 'https://api.github.com/repos/rutsky/setuptools-trial',
#     'labels_url': 'https://api.github.com/repos/rutsky/setuptools-trial/issues/118/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/rutsky/setuptools-trial/issues/118/comments',
#     'events_url': 'https://api.github.com/repos/rutsky/setuptools-trial/issues/118/events',
#     'html_url': 'https://github.com/rutsky/setuptools-trial/pull/118',
#     'id': 526354706,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQzODM1NzI2',
#     'number': 118,
#     'title': 'Update pytest to 5.3.0',
#     'user': {'login': 'pyup-bot',
#      'id': 16239342,
#      'node_id': 'MDQ6VXNlcjE2MjM5MzQy',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/16239342?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/pyup-bot',
#      'html_url': 'https://github.com/pyup-bot',
#      'followers_url': 'https://api.github.com/users/pyup-bot/followers',
#      'following_url': 'https://api.github.com/users/pyup-bot/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/pyup-bot/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/pyup-bot/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/pyup-bot/subscriptions',
#      'organizations_url': 'https://api.github.com/users/pyup-bot/orgs',
#      'repos_url': 'https://api.github.com/users/pyup-bot/repos',
#      'events_url': 'https://api.github.com/users/pyup-bot/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/pyup-bot/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2019-11-21T04:16:00Z',
#     'updated_at': '2019-11-28T06:24:19Z',
#     'closed_at': None,
#     'author_association': 'COLLABORATOR',
#     'pull_request': {'url': 'https://api.github.com/repos/rutsky/setuptools-trial/pulls/118',
#      'html_url': 'https://github.com/rutsky/setuptools-trial/pull/118',
#      'diff_url': 'https://github.com/rutsky/setuptools-trial/pull/118.diff',
#      'patch_url': 'https://github.com/rutsky/setuptools-trial/pull/118.patch'},
#     'body': '\nThis PR updates [pytest](https://pypi.org/project/pytest) from **3.4.0** to **5.3.0**.\n\n\n\n<details>\n  <summary>Changelog</summary>\n  \n  \n   ### 5.3.0\n   ```\n   =========================\n\nDeprecations\n------------\n\n- `6179 &lt;https://github.com/pytest-dev/pytest/issues/6179&gt;`_: The default value of ``junit_family`` option will change to ``xunit2`` in pytest 6.0, given\n  that this is the version supported by default in modern tools that manipulate this type of file.\n\n  In order to smooth the transition, pytest will issue a warning in case the ``--junitxml`` option\n  is given in the command line but ``junit_family`` is not explicitly configured in ``pytest.ini``.\n\n  For more information, `see the docs &lt;https://docs.pytest.org/en/latest/deprecations.htmljunit-family-default-value-change-to-xunit2&gt;`__.\n\n\n\nFeatures\n--------\n\n- `4488 &lt;https://github.com/pytest-dev/pytest/issues/4488&gt;`_: The pytest team has created the `pytest-reportlog &lt;https://github.com/pytest-dev/pytest-reportlog&gt;`__\n  plugin, which provides a new ``--report-log=FILE`` option that writes *report logs* into a file as the test session executes.\n\n  Each line of the report log contains a self contained JSON object corresponding to a testing event,\n  such as a collection or a test result report. The file is guaranteed to be flushed after writing\n  each line, so systems can read and process events in real-time.\n\n  The plugin is meant to replace the ``--resultlog`` option, which is deprecated and meant to be removed\n  in a future release. If you use ``--resultlog``, please try out ``pytest-reportlog`` and\n  provide feedback.\n\n\n- `4730 &lt;https://github.com/pytest-dev/pytest/issues/4730&gt;`_: When ``sys.pycache_prefix`` (Python 3.8+) is set, it will be used by pytest to cache test files changed by the assertion rewriting mechanism.\n\n  This makes it easier to benefit of cached ``.pyc`` files even on file systems without permissions.\n\n\n- `5515 &lt;https://github.com/pytest-dev/pytest/issues/5515&gt;`_: Allow selective auto-indentation of multiline log messages.\n\n  Adds command line option ``--log-auto-indent``, config option\n  ``log_auto_indent`` and support for per-entry configuration of\n  indentation behavior on calls to ``logging.log()``.\n\n  Alters the default for auto-indention from ``on`` to ``off``. This\n  restores the older behavior that existed prior to v4.6.0. This\n  reversion to earlier behavior was done because it is better to\n  activate new features that may lead to broken tests explicitly\n  rather than implicitly.\n\n\n- `5914 &lt;https://github.com/pytest-dev/pytest/issues/5914&gt;`_: ``pytester`` learned two new functions, `no_fnmatch_line &lt;https://docs.pytest.org/en/latest/reference.html_pytest.pytester.LineMatcher.no_fnmatch_line&gt;`_ and\n  `no_re_match_line &lt;https://docs.pytest.org/en/latest/reference.html_pytest.pytester.LineMatcher.no_re_match_line&gt;`_.\n\n  The functions are used to ensure the captured text *does not* match the given\n  pattern.\n\n  The previous idiom was to use ``re.match``:\n\n  .. code-block:: python\n\n      assert re.match(pat, result.stdout.str()) is None\n\n  Or the ``in`` operator:\n\n  .. code-block:: python\n\n      assert text in result.stdout.str()\n\n  But the new functions produce best output on failure.\n\n\n- `6057 &lt;https://github.com/pytest-dev/pytest/issues/6057&gt;`_: Added tolerances to complex values when printing ``pytest.approx``.\n\n  For example, ``repr(pytest.approx(3+4j))`` returns ``(3+4j) ± 5e-06 ∠ ±180°``. This is polar notation indicating a circle around the expected value, with a radius of 5e-06. For ``approx`` comparisons to return ``True``, the actual value should fall within this circle.\n\n\n- `6061 &lt;https://github.com/pytest-dev/pytest/issues/6061&gt;`_: Added the pluginmanager as an argument to ``pytest_addoption``\n  so that hooks can be invoked when setting up command line options. This i ...
#    'comment': {'url': 'https://api.github.com/repos/rutsky/setuptools-trial/issues/comments/559359211',
#     'html_url': 'https://github.com/rutsky/setuptools-trial/pull/118#issuecomment-559359211',
#     'issue_url': 'https://api.github.com/repos/rutsky/setuptools-trial/issues/118',
#     'id': 559359211,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU1OTM1OTIxMQ==',
#     'user': {'login': 'pyup-bot',
#      'id': 16239342,
#      'node_id': 'MDQ6VXNlcjE2MjM5MzQy',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/16239342?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/pyup-bot',
#      'html_url': 'https://github.com/pyup-bot',
#      'followers_url': 'https://api.github.com/users/pyup-bot/followers',
#      'following_url': 'https://api.github.com/users/pyup-bot/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/pyup-bot/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/pyup-bot/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/pyup-bot/subscriptions',
#      'organizations_url': 'https://api.github.com/users/pyup-bot/orgs',
#      'repos_url': 'https://api.github.com/users/pyup-bot/repos',
#      'events_url': 'https://api.github.com/users/pyup-bot/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/pyup-bot/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2019-11-28T06:24:19Z',
#     'updated_at': '2019-11-28T06:24:19Z',
#     'author_association': 'COLLABORATOR',
#     'body': 'Closing this in favor of #120'}},
#   'public': True,
#   'created_at': '2019-11-28T06:24:19Z'},
#  {'id': '10966253010',
#   'type': 'PushEvent',
#   'actor': {'id': 43338658,
#    'login': 'divpi4',
#    'display_login': 'divpi4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/divpi4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/43338658?'},
#   'repo': {'id': 222989913,
#    'name': 'divpi4/mslearn-tailspin-spacegame-web',
#    'url': 'https://api.github.com/repos/divpi4/mslearn-tailspin-spacegame-web'},
#   'payload': {'push_id': 4330559470,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/unit-tests',
#    'head': 'efd4955fe90dae89c22ec708fc9118982fc88e7b',
#    'before': '506aff7f2357c2329bca3e14ec531041d42e7a8e',
#    'commits': [{'sha': 'efd4955fe90dae89c22ec708fc9118982fc88e7b',
#      'author': {'email': 'divya.indira@mindtree.com', 'name': 'Divya Indira'},
#      'message': 'Run and publish unit tests',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/divpi4/mslearn-tailspin-spacegame-web/commits/efd4955fe90dae89c22ec708fc9118982fc88e7b'}]},
#   'public': True,
#   'created_at': '2019-11-28T06:24:19Z'},
#  {'id': '10966253002',
#   'type': 'IssuesEvent',
#   'actor': {'id': 6355370,
#    'login': 'ianschmitz',
#    'display_login': 'ianschmitz',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ianschmitz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6355370?'},
#   'repo': {'id': 63537249,
#    'name': 'facebook/create-react-app',
#    'url': 'https://api.github.com/repos/facebook/create-react-app'},
#   'payload': {'action': 'closed',
#    'issue': {'url': 'https://api.github.com/repos/facebook/create-react-app/issues/8040',
#     'repository_url': 'https://api.github.com/repos/facebook/create-react-app',
#     'labels_url': 'https://api.github.com/repos/facebook/create-react-app/issues/8040/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/facebook/create-react-app/issues/8040/comments',
#     'events_url': 'https://api.github.com/repos/facebook/create-react-app/issues/8040/events',
#     'html_url': 'https://github.com/facebook/create-react-app/issues/8040',
#     'id': 529705615,
#     'node_id': 'MDU6SXNzdWU1Mjk3MDU2MTU=',
#     'number': 8040,
#     'title': 'Dependencies for react-dev-utils@9.1.0 for published NPM package do not match repo files.',
#     'user': {'login': 'Nibblesh',
#      'id': 9124852,
#      'node_id': 'MDQ6VXNlcjkxMjQ4NTI=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/9124852?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Nibblesh',
#      'html_url': 'https://github.com/Nibblesh',
#      'followers_url': 'https://api.github.com/users/Nibblesh/followers',
#      'following_url': 'https://api.github.com/users/Nibblesh/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Nibblesh/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Nibblesh/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Nibblesh/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Nibblesh/orgs',
#      'repos_url': 'https://api.github.com/users/Nibblesh/repos',
#      'events_url': 'https://api.github.com/users/Nibblesh/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Nibblesh/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 1494610677,
#       'node_id': 'MDU6TGFiZWwxNDk0NjEwNjc3',
#       'url': 'https://api.github.com/repos/facebook/create-react-app/labels/issue:%20bug%20report',
#       'name': 'issue: bug report',
#       'color': 'f49118',
#       'default': False,
#       'description': ''},
#      {'id': 1467678098,
#       'node_id': 'MDU6TGFiZWwxNDY3Njc4MDk4',
#       'url': 'https://api.github.com/repos/facebook/create-react-app/labels/needs%20triage',
#       'name': 'needs triage',
#       'color': 'b5274d',
#       'default': False,
#       'description': ''}],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 1,
#     'created_at': '2019-11-28T05:44:56Z',
#     'updated_at': '2019-11-28T06:24:18Z',
#     'closed_at': '2019-11-28T06:24:18Z',
#     'author_association': 'NONE',
#     'body': "### Describe the bug\r\n\r\nFiles that are published to NPM for react-dev-utils@9.1.0 do not match current CRA master branch files.\r\n\r\n\r\nthese files should be the same, as they are both tagged as version 9.1.0\r\nhttps://unpkg.com/react-dev-utils@9.1.0/webpackHotDevClient.js\r\nhttps://raw.githubusercontent.com/facebook/create-react-app/master/packages/react-dev-utils/webpackHotDevClient.js\r\n\r\n### Did you try recovering your dependencies?\r\n\r\n<!--\r\n  Your module tree might be corrupted, and that might be causing the issues.\r\n  Let's try to recover it. First, delete these files and folders in your project:\r\n\r\n    * node_modules\r\n    * package-lock.json\r\n    * yarn.lock\r\n\r\n  Then you need to decide which package manager you prefer to use.\r\n  We support both npm (https://npmjs.com) and yarn (http://yarnpkg.com/).\r\n  However, **they can't be used together in one project** so you need to pick one.\r\n\r\n  If you decided to use npm, run this in your project directory:\r\n\r\n    npm install -g npm@latest\r\n    npm install\r\n\r\n  This should fix your project.\r\n\r\n  If you decided to use yarn, update it first (https://yarnpkg.com/en/docs/install).\r\n  Then run in your project directory:\r\n\r\n    yarn\r\n\r\n  This should fix your project.\r\n\r\n  Importantly, **if you decided to use yarn, you should never run `npm install` in the project**.\r\n  For example, yarn users should run `yarn add <library>` instead of `npm install <library>`.\r\n  Otherwise your project will break again.\r\n\r\n  Have you done all these steps and still see the issue?\r\n  Please paste the output of `npm --version` and/or `yarn --version` to confirm.\r\n-->\r\n\r\nyarn version: 1.19.1\r\n\r\n### Steps to reproduce\r\n\r\nDiff the two files linked\r\n\r\n### Expected behavior\r\n\r\nI have a fork of CRA which I use to publish a private version of react-scripts, I expected that when using the latest dependency version for react-dev-utils 9.1.0, it should be using the native WebSocket implementation as opposed to SockJS\r\n\r\nPlease note that when using CRA's version of react-scripts, it doesn't have the same issue, even though it is referencing the same version of react-dev-utils\r\n\r\n### Actual behavior\r\n\r\nMy version does not work because it is using an old version of react-dev-utils even though the version number is correct.\r\n\r\n![image](https://user-images.githubusercontent.com/9124852/69780096-5eea4c00-11fe-11ea-81ee-16afb39a7cb1.png)\r\n"}},
#   'public': True,
#   'created_at': '2019-11-28T06:24:19Z',
#   'org': {'id': 69631,
#    'login': 'facebook',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/facebook',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/69631?'}},
#  {'id': '10966253000',
#   'type': 'PushEvent',
#   'actor': {'id': 46572490,
#    'login': 'DreamsInCS',
#    'display_login': 'DreamsInCS',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/DreamsInCS',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/46572490?'},
#   'repo': {'id': 216908430,
#    'name': 'DreamsInCS/CAP4630-Machine-Learning-and-AI',
#    'url': 'https://api.github.com/repos/DreamsInCS/CAP4630-Machine-Learning-and-AI'},
#   'payload': {'push_id': 4330559462,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '24050bd0ee01dd12415b2a4d6d9e39c215b6765e',
#    'before': '96a426fc82d950ed357d49502eb70dbae821dfe5',
#    'commits': [{'sha': '24050bd0ee01dd12415b2a4d6d9e39c215b6765e',
#      'author': {'email': 'yoannierhermida@knights.ucf.edu',
#       'name': 'Yoannier Hermida'},
#      'message': 'Added HW3.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/DreamsInCS/CAP4630-Machine-Learning-and-AI/commits/24050bd0ee01dd12415b2a4d6d9e39c215b6765e'}]},
#   'public': True,
#   'created_at': '2019-11-28T06:24:19Z'},
#  {'id': '10966252997',
#   'type': 'PushEvent',
#   'actor': {'id': 57743948,
#    'login': 'uminoA',
#    'display_login': 'uminoA',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/uminoA',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/57743948?'},
#   'repo': {'id': 220870212,
#    'name': 'wst61/feel-free-connect',
#    'url': 'https://api.github.com/repos/wst61/feel-free-connect'},
#   'payload': {'push_id': 4330559458,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/develop',
#    'head': '8d0ff703f9423c3bc1b0ec1a2fec931ba7070f7e',
#    'before': 'de6a84efaed704d11e0e47aa63c6e8caf9b12ade',
#    'commits': [{'sha': '8d0ff703f9423c3bc1b0ec1a2fec931ba7070f7e',
#      'author': {'email': 'schwarz9665@gmail.com', 'name': 'umi'},
#      'message': 'レイアウトが崩れていたため細かい修正',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/wst61/feel-free-connect/commits/8d0ff703f9423c3bc1b0ec1a2fec931ba7070f7e'}]},
#   'public': True,
#   'created_at': '2019-11-28T06:24:18Z',
#   'org': {'id': 57605149,
#    'login': 'wst61',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/wst61',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/57605149?'}},
#  {'id': '10966252986',
#   'type': 'DeleteEvent',
#   'actor': {'id': 42799529,
#    'login': 'Tatsuki5274',
#    'display_login': 'Tatsuki5274',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Tatsuki5274',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/42799529?'},
#   'repo': {'id': 218169049,
#    'name': '18jn02-8/telledge',
#    'url': 'https://api.github.com/repos/18jn02-8/telledge'},
#   'payload': {'ref': 'CreateStudentShow',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-11-28T06:24:18Z',
#   'org': {'id': 56120496,
#    'login': '18jn02-8',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/18jn02-8',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56120496?'}},
#  {'id': '10966252993',
#   'type': 'PushEvent',
#   'actor': {'id': 303159,
#    'login': 'evanplaice',
#    'display_login': 'evanplaice',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/evanplaice',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/303159?'},
#   'repo': {'id': 181165738,
#    'name': 'vanillawc/wc-social-link',
#    'url': 'https://api.github.com/repos/vanillawc/wc-social-link'},
#   'payload': {'push_id': 4330559460,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '6fa517a7391fa544fbf274afb3d21cbc82c2e17e',
#    'before': '7e456eb3c58c50c3102280ee9058c42e7fcaf318',
#    'commits': [{'sha': '6fa517a7391fa544fbf274afb3d21cbc82c2e17e',
#      'author': {'email': 'evanplaice@gmail.com', 'name': 'Evan Plaice'},
#      'message': 'Update Demo Links]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/vanillawc/wc-social-link/commits/6fa517a7391fa544fbf274afb3d21cbc82c2e17e'}]},
#   'public': True,
#   'created_at': '2019-11-28T06:24:18Z',
#   'org': {'id': 49400083,
#    'login': 'vanillawc',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/vanillawc',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49400083?'}},
#  {'id': '10966252991',
#   'type': 'CreateEvent',
#   'actor': {'id': 24251510,
#    'login': 'keepondream',
#    'display_login': 'keepondream',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/keepondream',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24251510?'},
#   'repo': {'id': 224531675,
#    'name': 'keepondream/laravel-service',
#    'url': 'https://api.github.com/repos/keepondream/laravel-service'},
#   'payload': {'ref': 'v1.1',
#    'ref_type': 'tag',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-11-28T06:24:18Z'},
#  {'id': '10966252989',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 6355370,
#    'login': 'ianschmitz',
#    'display_login': 'ianschmitz',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ianschmitz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6355370?'},
#   'repo': {'id': 63537249,
#    'name': 'facebook/create-react-app',
#    'url': 'https://api.github.com/repos/facebook/create-react-app'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/facebook/create-react-app/issues/8040',
#     'repository_url': 'https://api.github.com/repos/facebook/create-react-app',
#     'labels_url': 'https://api.github.com/repos/facebook/create-react-app/issues/8040/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/facebook/create-react-app/issues/8040/comments',
#     'events_url': 'https://api.github.com/repos/facebook/create-react-app/issues/8040/events',
#     'html_url': 'https://github.com/facebook/create-react-app/issues/8040',
#     'id': 529705615,
#     'node_id': 'MDU6SXNzdWU1Mjk3MDU2MTU=',
#     'number': 8040,
#     'title': 'Dependencies for react-dev-utils@9.1.0 for published NPM package do not match repo files.',
#     'user': {'login': 'Nibblesh',
#      'id': 9124852,
#      'node_id': 'MDQ6VXNlcjkxMjQ4NTI=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/9124852?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Nibblesh',
#      'html_url': 'https://github.com/Nibblesh',
#      'followers_url': 'https://api.github.com/users/Nibblesh/followers',
#      'following_url': 'https://api.github.com/users/Nibblesh/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Nibblesh/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Nibblesh/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Nibblesh/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Nibblesh/orgs',
#      'repos_url': 'https://api.github.com/users/Nibblesh/repos',
#      'events_url': 'https://api.github.com/users/Nibblesh/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Nibblesh/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 1494610677,
#       'node_id': 'MDU6TGFiZWwxNDk0NjEwNjc3',
#       'url': 'https://api.github.com/repos/facebook/create-react-app/labels/issue:%20bug%20report',
#       'name': 'issue: bug report',
#       'color': 'f49118',
#       'default': False,
#       'description': ''},
#      {'id': 1467678098,
#       'node_id': 'MDU6TGFiZWwxNDY3Njc4MDk4',
#       'url': 'https://api.github.com/repos/facebook/create-react-app/labels/needs%20triage',
#       'name': 'needs triage',
#       'color': 'b5274d',
#       'default': False,
#       'description': ''}],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2019-11-28T05:44:56Z',
#     'updated_at': '2019-11-28T06:24:18Z',
#     'closed_at': '2019-11-28T06:24:18Z',
#     'author_association': 'NONE',
#     'body': "### Describe the bug\r\n\r\nFiles that are published to NPM for react-dev-utils@9.1.0 do not match current CRA master branch files.\r\n\r\n\r\nthese files should be the same, as they are both tagged as version 9.1.0\r\nhttps://unpkg.com/react-dev-utils@9.1.0/webpackHotDevClient.js\r\nhttps://raw.githubusercontent.com/facebook/create-react-app/master/packages/react-dev-utils/webpackHotDevClient.js\r\n\r\n### Did you try recovering your dependencies?\r\n\r\n<!--\r\n  Your module tree might be corrupted, and that might be causing the issues.\r\n  Let's try to recover it. First, delete these files and folders in your project:\r\n\r\n    * node_modules\r\n    * package-lock.json\r\n    * yarn.lock\r\n\r\n  Then you need to decide which package manager you prefer to use.\r\n  We support both npm (https://npmjs.com) and yarn (http://yarnpkg.com/).\r\n  However, **they can't be used together in one project** so you need to pick one.\r\n\r\n  If you decided to use npm, run this in your project directory:\r\n\r\n    npm install -g npm@latest\r\n    npm install\r\n\r\n  This should fix your project.\r\n\r\n  If you decided to use yarn, update it first (https://yarnpkg.com/en/docs/install).\r\n  Then run in your project directory:\r\n\r\n    yarn\r\n\r\n  This should fix your project.\r\n\r\n  Importantly, **if you decided to use yarn, you should never run `npm install` in the project**.\r\n  For example, yarn users should run `yarn add <library>` instead of `npm install <library>`.\r\n  Otherwise your project will break again.\r\n\r\n  Have you done all these steps and still see the issue?\r\n  Please paste the output of `npm --version` and/or `yarn --version` to confirm.\r\n-->\r\n\r\nyarn version: 1.19.1\r\n\r\n### Steps to reproduce\r\n\r\nDiff the two files linked\r\n\r\n### Expected behavior\r\n\r\nI have a fork of CRA which I use to publish a private version of react-scripts, I expected that when using the latest dependency version for react-dev-utils 9.1.0, it should be using the native WebSocket implementation as opposed to SockJS\r\n\r\nPlease note that when using CRA's version of react-scripts, it doesn't have the same issue, even though it is referencing the same version of react-dev-utils\r\n\r\n### Actual behavior\r\n\r\nMy version does not work because it is using an old version of react-dev-utils even though the version number is correct.\r\n\r\n![image](https://user-images.githubusercontent.com/9124852/69780096-5eea4c00-11fe-11ea-81ee-16afb39a7cb1.png)\r\n"},
#    'comment': {'url': 'https://api.github.com/repos/facebook/create-react-app/issues/comments/559359208',
#     'html_url': 'https://github.com/facebook/create-react-app/issues/8040#issuecomment-559359208',
#     'issue_url': 'https://api.github.com/repos/facebook/create-react-app/issues/8040',
#     'id': 559359208,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU1OTM1OTIwOA==',
#     'user': {'login': 'ianschmitz',
#      'id': 6355370,
#      'node_id': 'MDQ6VXNlcjYzNTUzNzA=',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/6355370?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/ianschmitz',
#      'html_url': 'https://github.com/ianschmitz',
#      'followers_url': 'https://api.github.com/users/ianschmitz/followers',
#      'following_url': 'https://api.github.com/users/ianschmitz/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/ianschmitz/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/ianschmitz/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/ianschmitz/subscriptions',
#      'organizations_url': 'https://api.github.com/users/ianschmitz/orgs',
#      'repos_url': 'https://api.github.com/users/ianschmitz/repos',
#      'events_url': 'https://api.github.com/users/ianschmitz/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/ianschmitz/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2019-11-28T06:24:18Z',
#     'updated_at': '2019-11-28T06:24:18Z',
#     'author_association': 'COLLABORATOR',
#     'body': "The new version hasn't been published to npm yet. I recommend when maintaining a fork you instead use a tagged commit to reference instead of the tip of master."}},
#   'public': True,
#   'created_at': '2019-11-28T06:24:18Z',
#   'org': {'id': 69631,
#    'login': 'facebook',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/facebook',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/69631?'}},
#  {'id': '10966252985',
#   'type': 'PushEvent',
#   'actor': {'id': 57659591,
#    'login': '1076464015',
#    'display_login': '1076464015',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/1076464015',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/57659591?'},
#   'repo': {'id': 221888491,
#    'name': 'jxf010723/java30project',
#    'url': 'https://api.github.com/repos/jxf010723/java30project'},
#   'payload': {'push_id': 4330559450,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/FJ',
#    'head': '5e2e71b76ccb61122c85b882bea7b275099edbe3',
#    'before': '4c04b391b49a2b39c9094a880eb1d3b5086b1163',
#    'commits': [{'sha': '5e2e71b76ccb61122c85b882bea7b275099edbe3',
#      'author': {'email': '1076464015@qq.com', 'name': '1076464015'},
#      'message': '2019-11-28fj2',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jxf010723/java30project/commits/5e2e71b76ccb61122c85b882bea7b275099edbe3'}]},
#   'public': True,
#   'created_at': '2019-11-28T06:24:18Z'},
#  {'id': '10966252978',
#   'type': 'PushEvent',
#   'actor': {'id': 23629483,
#    'login': 'damien-bayes',
#    'display_login': 'damien-bayes',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/damien-bayes',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23629483?'},
#   'repo': {'id': 137471659,
#    'name': 'damien-bayes/bayesian-tmdb-client',
#    'url': 'https://api.github.com/repos/damien-bayes/bayesian-tmdb-client'},
#   'payload': {'push_id': 4330559451,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/development',
#    'head': 'b5c2eb7bd4f9aad97ac85ec08b02f17ff8926837',
#    'before': 'f00f40ee2336db7052c7a11c5ba25d216529b2ba',
#    'commits': [{'sha': 'b5c2eb7bd4f9aad97ac85ec08b02f17ff8926837',
#      'author': {'email': 'damien.bayes.db@gmail.com', 'name': 'Damien Bayes'},
#      'message': 'Language changer and FontAwesome Icons',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/damien-bayes/bayesian-tmdb-client/commits/b5c2eb7bd4f9aad97ac85ec08b02f17ff8926837'}]},
#   'public': True,
#   'created_at': '2019-11-28T06:24:18Z'},
#  {'id': '10966252966',
#   'type': 'PushEvent',
#   'actor': {'id': 52979326,
#    'login': 'Mozziemist',
#    'display_login': 'Mozziemist',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Mozziemist',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52979326?'},
#   'repo': {'id': 207887546,
#    'name': 'Mozziemist/AssureX',
#    'url': 'https://api.github.com/repos/Mozziemist/AssureX'},
#   'payload': {'push_id': 4330559446,
#    'size': 4,
#    'distinct_size': 4,
#    'ref': 'refs/heads/development',
#    'head': '2461e6b311c3137e99c7f1f749f2a9b94159a511',
#    'before': '26f26c4382a627fe8b6ade53728e3cad96fb1b60',
#    'commits': [{'sha': '817dced4cb53545b458ce90920bcfb2388734af7',
#      'author': {'email': 'ben.stanke@me.com', 'name': 'Clientings'},
#      'message': "added bug fixes\n\nthe speed page now saves the username before reloading\n\nthe darkmode can't be changed unless isEngineOn is false",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Mozziemist/AssureX/commits/817dced4cb53545b458ce90920bcfb2388734af7'},
#     {'sha': 'ceca4c29dd2dd963386313d4a57105df382b833d',
#      'author': {'email': 'ben.stanke@me.com', 'name': 'Clientings'},
#      'message': 'Bug fixes 11-27-19\n\ncan now edit user and pswrd text',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Mozziemist/AssureX/commits/ceca4c29dd2dd963386313d4a57105df382b833d'},
#     {'sha': '382bdb3946654ebeb7888339834bf1bd19b370cc',
#      'author': {'email': '52979326+Mozziemist@users.noreply.github.com',
#       'name': 'Mozziemist'},
#      'message': "Merge branch 'development' into development",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Mozziemist/AssureX/commits/382bdb3946654ebeb7888339834bf1bd19b370cc'},
#     {'sha': '2461e6b311c3137e99c7f1f749f2a9b94159a511',
#      'author': {'email': '52979326+Mozziemist@users.noreply.github.com',
#       'name': 'Mozziemist'},
#      'message': 'Merge pull request #29 from Clientings/development\n\nBig Fixes',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Mozziemist/AssureX/commits/2461e6b311c3137e99c7f1f749f2a9b94159a511'}]},
#   'public': True,
#   'created_at': '2019-11-28T06:24:18Z'},
#  {'id': '10966252958',
#   'type': 'PushEvent',
#   'actor': {'id': 49300109,
#    'login': 'zhorakhanov1',
#    'display_login': 'zhorakhanov1',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/zhorakhanov1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49300109?'},
#   'repo': {'id': 215981866,
#    'name': 'zhorakhanov1/Web-Fundamentals-',
#    'url': 'https://api.github.com/repos/zhorakhanov1/Web-Fundamentals-'},
#   'payload': {'push_id': 4330559447,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '85c0d648b6905ecb9eeb1d4b42aad0005b747c91',
#    'before': 'b11c0172545b2c314b058e176f5d7fad76386c3c',
#    'commits': [{'sha': '85c0d648b6905ecb9eeb1d4b42aad0005b747c91',
#      'author': {'email': '49300109+zhorakhanov1@users.noreply.github.com',
#       'name': 'zhorakhanov1'},
#      'message': 'Create qwerty',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/zhorakhanov1/Web-Fundamentals-/commits/85c0d648b6905ecb9eeb1d4b42aad0005b747c91'}]},
#   'public': True,
#   'created_at': '2019-11-28T06:24:18Z'},
#  {'id': '10966252965',
#   'type': 'PushEvent',
#   'actor': {'id': 97740,
#    'login': 'samrain',
#    'display_login': 'samrain',
#    'gravatar_id': '',
# ...
#       'issue_comment_url': 'https://api.github.com/repos/PasteUs/PasteMeFrontend/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/PasteUs/PasteMeFrontend/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/PasteUs/PasteMeFrontend/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/PasteUs/PasteMeFrontend/merges',
#       'archive_url': 'https://api.github.com/repos/PasteUs/PasteMeFrontend/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/PasteUs/PasteMeFrontend/downloads',
#       'issues_url': 'https://api.github.com/repos/PasteUs/PasteMeFrontend/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/PasteUs/PasteMeFrontend/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/PasteUs/PasteMeFrontend/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/PasteUs/PasteMeFrontend/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/PasteUs/PasteMeFrontend/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/PasteUs/PasteMeFrontend/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/PasteUs/PasteMeFrontend/deployments',
#       'created_at': '2019-06-22T14:46:22Z',
#       'updated_at': '2019-10-25T06:49:21Z',
#       'pushed_at': '2019-11-28T06:24:15Z',
#       'git_url': 'git://github.com/PasteUs/PasteMeFrontend.git',
#       'ssh_url': 'git@github.com:PasteUs/PasteMeFrontend.git',
#       'clone_url': 'https://github.com/PasteUs/PasteMeFrontend.git',
#       'svn_url': 'https://github.com/PasteUs/PasteMeFrontend',
#       'homepage': None,
#       'size': 5728,
#       'stargazers_count': 4,
#       'watchers_count': 4,
#       'language': 'Vue',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 4,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 11,
#       'license': {'key': 'gpl-3.0',
#        'name': 'GNU General Public License v3.0',
#        'spdx_id': 'GPL-3.0',
#        'url': 'https://api.github.com/licenses/gpl-3.0',
#        'node_id': 'MDc6TGljZW5zZTk='},
#       'forks': 4,
#       'open_issues': 11,
#       'watchers': 4,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/PasteUs/PasteMeFrontend/pulls/148'},
#      'html': {'href': 'https://github.com/PasteUs/PasteMeFrontend/pull/148'},
#      'issue': {'href': 'https://api.github.com/repos/PasteUs/PasteMeFrontend/issues/148'},
#      'comments': {'href': 'https://api.github.com/repos/PasteUs/PasteMeFrontend/issues/148/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/PasteUs/PasteMeFrontend/pulls/148/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/PasteUs/PasteMeFrontend/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/PasteUs/PasteMeFrontend/pulls/148/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/PasteUs/PasteMeFrontend/statuses/05111b36aebcae2e3278aa0a351fa7f9808250dd'}},
#     'author_association': 'CONTRIBUTOR',
#     'merged': False,
#     'mergeable': True,
#     'rebaseable': True,
#     'mergeable_state': 'clean',
#     'merged_by': None,
#     'comments': 1,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 8,
#     'deletions': 8,
#     'changed_files': 2}},
#   'public': True,
#   'created_at': '2019-11-28T06:24:18Z',
#   'org': {'id': 54676094,
#    'login': 'PasteUs',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/PasteUs',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54676094?'}},
#  {'id': '10966252938',
#   'type': 'ForkEvent',
#   'actor': {'id': 587943,
#    'login': 'lainproliant',
#    'display_login': 'lainproliant',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lainproliant',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/587943?'},
#   'repo': {'id': 128823,
#    'name': 'plasticboy/vim-markdown',
#    'url': 'https://api.github.com/repos/plasticboy/vim-markdown'},
#   'payload': {'forkee': {'id': 224584364,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkyMjQ1ODQzNjQ=',
#     'name': 'vim-markdown',
#     'full_name': 'lainproliant/vim-markdown',
#     'private': False,
#     'owner': {'login': 'lainproliant',
#      'id': 587943,
#      'node_id': 'MDQ6VXNlcjU4Nzk0Mw==',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/587943?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/lainproliant',
#      'html_url': 'https://github.com/lainproliant',
#      'followers_url': 'https://api.github.com/users/lainproliant/followers',
#      'following_url': 'https://api.github.com/users/lainproliant/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/lainproliant/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/lainproliant/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/lainproliant/subscriptions',
#      'organizations_url': 'https://api.github.com/users/lainproliant/orgs',
#      'repos_url': 'https://api.github.com/users/lainproliant/repos',
#      'events_url': 'https://api.github.com/users/lainproliant/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/lainproliant/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/lainproliant/vim-markdown',
#     'description': 'Markdown Vim Mode',
#     'fork': True,
#     'url': 'https://api.github.com/repos/lainproliant/vim-markdown',
#     'forks_url': 'https://api.github.com/repos/lainproliant/vim-markdown/forks',
#     'keys_url': 'https://api.github.com/repos/lainproliant/vim-markdown/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/lainproliant/vim-markdown/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/lainproliant/vim-markdown/teams',
#     'hooks_url': 'https://api.github.com/repos/lainproliant/vim-markdown/hooks',
#     'issue_events_url': 'https://api.github.com/repos/lainproliant/vim-markdown/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/lainproliant/vim-markdown/events',
#     'assignees_url': 'https://api.github.com/repos/lainproliant/vim-markdown/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/lainproliant/vim-markdown/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/lainproliant/vim-markdown/tags',
#     'blobs_url': 'https://api.github.com/repos/lainproliant/vim-markdown/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/lainproliant/vim-markdown/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/lainproliant/vim-markdown/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/lainproliant/vim-markdown/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/lainproliant/vim-markdown/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/lainproliant/vim-markdown/languages',
#     'stargazers_url': 'https://api.github.com/repos/lainproliant/vim-markdown/stargazers',
#     'contributors_url': 'https://api.github.com/repos/lainproliant/vim-markdown/contributors',
#     'subscribers_url': 'https://api.github.com/repos/lainproliant/vim-markdown/subscribers',
#     'subscription_url': 'https://api.github.com/repos/lainproliant/vim-markdown/subscription',
#     'commits_url': 'https://api.github.com/repos/lainproliant/vim-markdown/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/lainproliant/vim-markdown/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/lainproliant/vim-markdown/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/lainproliant/vim-markdown/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/lainproliant/vim-markdown/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/lainproliant/vim-markdown/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/lainproliant/vim-markdown/merges',
#     'archive_url': 'https://api.github.com/repos/lainproliant/vim-markdown/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/lainproliant/vim-markdown/downloads',
#     'issues_url': 'https://api.github.com/repos/lainproliant/vim-markdown/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/lainproliant/vim-markdown/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/lainproliant/vim-markdown/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/lainproliant/vim-markdown/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/lainproliant/vim-markdown/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/lainproliant/vim-markdown/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/lainproliant/vim-markdown/deployments',
#     'created_at': '2019-11-28T06:24:17Z',
#     'updated_at': '2019-11-27T15:34:36Z',
#     'pushed_at': '2019-10-04T11:10:08Z',
#     'git_url': 'git://github.com/lainproliant/vim-markdown.git',
#     'ssh_url': 'git@github.com:lainproliant/vim-markdown.git',
#     'clone_url': 'https://github.com/lainproliant/vim-markdown.git',
#     'svn_url': 'https://github.com/lainproliant/vim-markdown',
#     'homepage': 'http://plasticboy.com/markdown-vim-mode/',
#     'size': 454,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master',
#     'public': True}},
#   'public': True,
#   'created_at': '2019-11-28T06:24:18Z'},
#  {'id': '10966252926',
#   'type': 'PushEvent',
#   'actor': {'id': 3372300,
#    'login': 'joker-eph',
#    'display_login': 'joker-eph',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/joker-eph',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3372300?'},
#   'repo': {'id': 217675284,
#    'name': 'joker-eph/llvm-project-with-mlir',
#    'url': 'https://api.github.com/repos/joker-eph/llvm-project-with-mlir'},
#   'payload': {'push_id': 4330559427,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '8fcddd4f685324f26595615992971dead897f2e4',
#    'before': '5aa95faf0def5a12100f1905dc9cbae421d437d2',
#    'commits': [{'sha': '8fcddd4f685324f26595615992971dead897f2e4',
#      'author': {'email': 'aminim@google.com', 'name': 'Mehdi Amini'},
#      'message': 'Import MLIR into the LLVM tree',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/joker-eph/llvm-project-with-mlir/commits/8fcddd4f685324f26595615992971dead897f2e4'}]},
#   'public': True,
#   'created_at': '2019-11-28T06:24:18Z'},
#  {'id': '10966252925',
#   'type': 'IssuesEvent',
#   'actor': {'id': 24617781,
#    'login': 'JayadevHaddadi',
#    'display_login': 'JayadevHaddadi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/JayadevHaddadi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24617781?'},
#   'repo': {'id': 218446560,
#    'name': 'Campus-Advisors/campus-advisor-training-JayadevHaddadi',
#    'url': 'https://api.github.com/repos/Campus-Advisors/campus-advisor-training-JayadevHaddadi'},
#   'payload': {'action': 'opened',
#    'issue': {'url': 'https://api.github.com/repos/Campus-Advisors/campus-advisor-training-JayadevHaddadi/issues/1',
#     'repository_url': 'https://api.github.com/repos/Campus-Advisors/campus-advisor-training-JayadevHaddadi',
#     'labels_url': 'https://api.github.com/repos/Campus-Advisors/campus-advisor-training-JayadevHaddadi/issues/1/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/Campus-Advisors/campus-advisor-training-JayadevHaddadi/issues/1/comments',
#     'events_url': 'https://api.github.com/repos/Campus-Advisors/campus-advisor-training-JayadevHaddadi/issues/1/events',
#     'html_url': 'https://github.com/Campus-Advisors/campus-advisor-training-JayadevHaddadi/issues/1',
#     'id': 529717161,
#     'node_id': 'MDU6SXNzdWU1Mjk3MTcxNjE=',
#     'number': 1,
#     'title': 'Module 1.1 Assignment',
#     'user': {'login': 'JayadevHaddadi',
#      'id': 24617781,
#      'node_id': 'MDQ6VXNlcjI0NjE3Nzgx',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/24617781?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/JayadevHaddadi',
#      'html_url': 'https://github.com/JayadevHaddadi',
#      'followers_url': 'https://api.github.com/users/JayadevHaddadi/followers',
#      'following_url': 'https://api.github.com/users/JayadevHaddadi/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/JayadevHaddadi/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/JayadevHaddadi/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/JayadevHaddadi/subscriptions',
#      'organizations_url': 'https://api.github.com/users/JayadevHaddadi/orgs',
#      'repos_url': 'https://api.github.com/users/JayadevHaddadi/repos',
#      'events_url': 'https://api.github.com/users/JayadevHaddadi/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/JayadevHaddadi/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2019-11-28T06:24:17Z',
#     'updated_at': '2019-11-28T06:24:17Z',
#     'closed_at': None,
#     'author_association': 'COLLABORATOR',
#     'body': 'Given what you have learned about Git, why would you want to use Git in your classroom?'}},
#   'public': True,
#   'created_at': '2019-11-28T06:24:18Z',
#   'org': {'id': 36317571,
#    'login': 'Campus-Advisors',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Campus-Advisors',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36317571?'}},
#  {'id': '10966252916',
#   'type': 'PushEvent',
#   'actor': {'id': 7415711,
#    'login': 'AzureZhen',
#    'display_login': 'AzureZhen',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/AzureZhen',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7415711?'},
#   'repo': {'id': 221334247,
#    'name': 'AzureZhen/Mine-and-Slash-AutoCompat-114',
#    'url': 'https://api.github.com/repos/AzureZhen/Mine-and-Slash-AutoCompat-114'},
#   'payload': {'push_id': 4330559425,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/1.12.2',
#    'head': '9fdbe8ac5953fedb55d8245b7beb90ef4e491495',
#    'before': 'ccb9883b722f31a72eda219217a7aa6e365815ee',
#    'commits': [{'sha': '9fdbe8ac5953fedb55d8245b7beb90ef4e491495',
#      'author': {'email': 'rcraft@cyberconnects2.com', 'name': 'AzureZhen'},
#      'message': 'alright time to start this bitch',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/AzureZhen/Mine-and-Slash-AutoCompat-114/commits/9fdbe8ac5953fedb55d8245b7beb90ef4e491495'}]},
#   'public': True,
#   'created_at': '2019-11-28T06:24:18Z'},
#  {'id': '10966252913',
#   'type': 'CreateEvent',
#   'actor': {'id': 53108186,
#    'login': 'codestar-github-bot-1',
#    'display_login': 'codestar-github-bot-1',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/codestar-github-bot-1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/53108186?'},
#   'repo': {'id': 224584351,
#    'name': 'codestar-github-bot-1/user-public-seeded-repo-ap-southeast-2',
#    'url': 'https://api.github.com/repos/codestar-github-bot-1/user-public-seeded-repo-ap-southeast-2'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Seeded Repository created by CFN',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-11-28T06:24:18Z'}]

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
import requests
import json

r = requests.get('https://cat-fact.herokuapp.com/facts')
response = r.text
json.loads(response)
# Out:
# {'all': [{'_id': '5b4911940508220014ccfe94',
#    'text': 'By the time a cat is 9 years old, it will only have been awake for three years of its life.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '58e008ad0aac31001185ed0c',
#    'text': "The frequency of a domestic cat's purr is the same at which muscles and bones repair themselves.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '5955792c7b77520020799431',
#    'text': 'Cats "knead" because of seperation from their mothers',
#    'type': 'cat',
#    'user': {'_id': '595579027b77520020799430',
#     'name': {'first': 'Is It Still Memes That', 'last': 'Make You Sweat?'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '59a60b8e6acf530020f3586e',
#    'text': 'Cat owners are 17% more likely to have a graduate degree than non cat owners.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '58e008b80aac31001185ed0d',
#    'text': 'Adult cats only meow to communicate with humans.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e009650aac31001185ed13',
#    'text': 'In the 1960s, the CIA tried to turn a cat into a bonafide spy by implanting a microphone into her ear and a radio transmitter at the base of her skull. She somehow survived the surgery but got hit by a taxi on her first mission.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00b2b0aac31001185ed1f',
#    'text': "A cat has five toes on his front paws, and four on the back, unless he's a polydactyl.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00be30aac31001185edfe',
#    'text': 'Cats use their whiskers to detect if they can fit through a space.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00b4d0aac31001185ed22',
#    'text': 'Original kitty litter was made out of sand but it was replaced by more absorbent clay in 1948.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b199196ce456e001424256a',
#    'text': 'Cats can distinguish different flavors in water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b1b411d841d9700146158d9',
#    'text': 'The Egyptian Mau’s name is derived from the Middle Egyptian word mjw, which means cat. But contrary to its name, it’s unclear whether the modern Egyptian Mau actually originated in Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b4912c60508220014ccfe99',
#    'text': 'Cats aren’t the only animals that purr — squirrels, lemurs, elephants, and even gorillas purr too.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e007db0aac31001185ecf7',
#    'text': 'There are cats who have survived falls from over 32 stories (320 meters) onto concrete.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e008800aac31001185ed07',
#    'text': 'Wikipedia has a recording of a cat meowing, because why not?',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e009790aac31001185ed14',
#    'text': 'The technical term for "hairball" is "bezoar."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e00a120aac31001185ed17',
#    'text': "A cat's brain is 90% similar to a human's — more similar than to a dog's.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '591d9b2f227c1a0020d26823',
#    'text': 'Every year, nearly four million cats are eaten in China as a delicacy.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5974fb4dfedacb0020b5b4cc',
#    'text': 'Cats can survive falls from up to 65 feet or more.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '59a60ba66acf530020f35873',
#    'text': "Most cats don't like water because their coats do not insulate them well enough.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5a4d76916ef087002174c28b',
#    'text': 'A cat’s nose pad is ridged with a unique pattern, just like the fingerprint of a human.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '59951d5ef2db18002031693c',
#    'text': 'America’s cats, including housecats that adventure outdoors and feral cats, kill between 1.3 billion and 4.0 billion birds in a year.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b01a447c6914f0014cc9a30',
#    'text': "The special sensory organ called the Jacobson's organ allows a cat to have 14 times the sense of smell of a human. It consists of two fluid-filled sacs that connect to the cat's nasal cavity and is located on the roof of their mouth behind their teeth.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b1b4014841d9700146158d0',
#    'text': 'In 1879, Belgium unsuccessfully tried to use cats to deliver mail.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b1b4055841d9700146158d3',
#    'text': 'Scottish sailer Alexander Selkirk once survived for 4 years on a deserted island thanks to feral cats that protected him from large rats during the night.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b3bd7d24cf4e10014bfd199',
#    'text': 'The myth that a cat has nine lives comes from their ability to jump and land from high places. The number 9 is believed by some to originate from William Shakespeare\'s Romeo and Juliet: "A cat has nine lives. For three he plays, for three he strays, and for the last three he stays."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b453e380fd3a600147f32f3',
#    'text': 'Exposure to UV light with hairless or partially-hairless cats can result in sunburn, even during cloudy or shady conditions. If your cat risks overexposure, consider applying sunscreen daily.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e008780aac31001185ed05',
#    'text': 'Owning a cat can reduce the risk of stroke and heart attack by a third.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58f9b96132ffea00208fe9b7',
#    'text': 'rerewr',
#    'type': 'cat',
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '590b9d90229d260020af0b06',
#    'text': "Evidence suggests domesticated cats have been around since 3600 B.C., 2,000 years before Egypt's pharaohs.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58923f2fc3878c0011784c79',
#    'text': "I don't know anything about cats.",
#    'type': 'cat',
#    'user': {'_id': '5887e9f65c873e001103688d',
#     'name': {'first': 'Jackson', 'last': 'Sippe'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b8b0aac31001185edf8',
#    'text': 'A cat can jump up to six times its length.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00c080aac31001185ee01',
#    'text': 'Cats only sweat through their foot pads.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '590c752b5363e000200d5141',
#    'text': "Kangaroos can't hop backwards",
#    'type': 'cat',
#    'user': {'_id': '590c74045363e000200d5140',
#     'name': {'first': 'Hampton', 'last': 'McGrath'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '599f89639a11040c4a163440',
#    'text': 'Here is a video of some cats in zero gravity. youtu.be/O9XtK6R1QAk',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59cd7a97c828120020f7d3a1',
#    'text': 'Since cats treat us like cats and depend on us for things like food, water, and opening the door to let them out, they do recognize, that we are in some way in charge — the “big cat” in the shared territory. As territorial animals, our cats are constantly wondering why we’re not doing other cat things that the big cat would normally do in their territory. In fact, the “let me in, let me out, let me in” phenomenon is a good example. The bigger cat ostensibly rules the territory and therefore should be the one patrolling and marking it with pee so other cats stay away. But since humans don’t do this, indoor-outdoor cats reluctantly take on the role themselves. The apparent neuroticism of cats wanting to go outside every five minutes only to be let right back in is funny to us because it seems so silly and unnecessary. But to the cats, it’s very necessary (and frustrating) to cover for their dumb pals.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b40cc841d9700146158d7',
#    'text': 'In most US states, declawing cats is legal but in the European Union it is not.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4911e60508220014ccfe95',
#    'text': 'A female cat is called a “molly” or a “queen”.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58cafac6ffae36001108d586',
#    'text': 'Cats have fur',
#    'type': 'cat',
#    'user': {'_id': '58c86fe52341fc0011d7b151',
#     'name': {'first': 'Alex', 'last': 'Simon'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e007cc0aac31001185ecf5',
#    'text': 'Cats are the most popular pet in the United States: There are 88 million pet cats and 74 million dogs.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008510aac31001185ecfe',
#    'text': 'In tigers and tabbies, the middle of the tongue is covered in backward-pointing spines, used for breaking off and gripping meat.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008c50aac31001185ed0e',
#    'text': "The world's richest cat is worth $13 million after his human passed away and left her fortune to him.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008630aac31001185ed01',
#    'text': 'When cats grimace, they are usually "taste-scenting." They have an extra organ that, with some breathing control, allows the cats to taste-sense the air.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008a30aac31001185ed0b',
#    'text': "A cat's purr may be a form of self-healing, as it can be a sign of nervousness as well as contentment.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008d00aac31001185ed0f',
#    'text': 'Your cat recognizes your voice but just acts too cool to care (probably because they are).',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00a850aac31001185ed1a',
#    'text': 'Cats have a longer-term memory than dogs, especially when they learn by actually doing rather than simply seeing.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b3a0aac31001185ed20',
#    'text': 'Polydactyl cats are also referred to as "Hemingway cats" because the author was so fond of them.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b5f0aac31001185ed24',
#    'text': 'When asked if her husband had any hobbies, Mary Todd Lincoln is said to have replied "cats."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00bdb0aac31001185edfd',
#    'text': 'Cats can change their meow to manipulate a human. They often imitate a human baby when they need food, for example.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b820aac31001185edf7',
#    'text': "One legend claims that cats were created when a lion on Noah's Ark sneezed and two kittens came out.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bce227c1a0020d26827',
#    'text': 'In Korea and Japan, there is a Cat Cafe where you can go to drink coffee and hang out with cats for hours.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00ba00aac31001185edfa',
#    'text': "When cats leave their poop uncovered, it is a sign of aggression to let you know they don't fear you.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bab227c1a0020d26825',
#    'text': 'Owning a cat can reduce the risk of heart attacks and strokes by more than a third, researchers found.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '596e4989b863f300203102f4',
#    'text': 'Black cats are less likely to be adopted because of their "appearance".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59a60bae6acf530020f35875',
#    'text': 'Cats were mythic symbols of divinity in ancient Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59d297b7c6671e0020957eb9',
#    'text': 'Kittens sleep so much because the growth hormone is only released when they sleep.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a038d5a8e3dbc001f719791',
#    'text': 'Cats have 38 chromosomes in each zygote cell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a038dae8e3dbc001f719792',
#    'text': "Cucumbers look enough like a snake to cause a cat's instinctive fear of snakes to kick in, causing it to panic and flee.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a36ec5fae877e0021ed79f5',
#    'text': 'It has been estimated that a cat yawns on the average of 109,500 times in his life.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4bfbbab0810f0021748b91',
#    'text': "Lil' Bunny Sue Roux is a cat who was born with no front legs, and walks upright like a kangaroo. https://www.instagram.com/lilbunnysueroux",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d766c6ef087002174c288',
#    'text': 'Some Siamese cats appear cross-eyed because the nerves from the left side of the brain go to mostly the right eye and the nerves from the right side of the brain go mostly to the left eye. This causes some double vision, which the cat tries to correct by “crossing” its eyes.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b3feb841d9700146158cf',
#    'text': 'In Islam, cats are revered for their cleanliness. Muhammad is reported to have said that "a love of cats is an aspect of faith".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b4065841d9700146158d4',
#    'text': 'A cat named Emmy lived aboard the RMS Empress of Ireland and she never missed a voyage. On May 28,1914, however, she refused to board. The ship left without her and then sank the following day.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b408a841d9700146158d5',
#    'text': 'Domestic cats will try not to drink from a water bowl that is next to their food. This is because in the wild, water next to their kill could be contaminated.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b3d8e4960d3890713ca39a8',
#    'text': 'A Chinese cat named Baidianr (meaning "white spot") had a unique ability to choose World Cup winners. He predicted the winner of the soccer competition 6 years in a row, before he died on June 2, 2018, just before the event ended.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4909af0508220014ccfe8a',
#    'text': 'Cats have a layer called the tapetum lucidum just behind their retina which reflects light inside the eye, helping it capture more light. This reflected light is the glow you see when taking a photo of a cat with the flash on.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e009390aac31001185ed10',
#    'text': "Most cats are lactose intolerant, and milk can cause painful stomach cramps and diarrhea. It's best to forego the milk and just give your cat the standard: clean, cool drinking water.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5c6a105dc2d7a200140f69a0',
#    'text': 'When cats run, their backs contract and extend to give them maximum stride. Their shoulder blades are not attached with bone, but with muscle, and this gives a cat even greater extension and speed.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59664b1f474ba80020ef8592',
#    'text': "Your cat's instincts tell her that a paperweight or knickknack could turn out to be a mouse. Her poking paw would send it scurrying, giving her a good game. This is probably why cats always seem to be knocking the glasses off your counter tops!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59669484bf604b00205c20e3',
#    'text': 'The fear of cats is called "Ailurophobia"',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '596f4f50a8d3440020e2d77d',
#    'text': 'Due to the controversy, though loved by most, the Kashmir is overlooked by many cat fanciers.',
#    'type': 'cat',
#    'user': {'_id': '596ea14ed4d9720020401f7b',
#     'name': {'first': 'Kenny', 'last': 'Corsig'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b896acf530020f3586d',
#    'text': 'Cat owners are 25% likely to pick George Harrison as their favorite Beatle.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b936acf530020f3586f',
#    'text': 'Only 11.5% of people consider themselves "cat people".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b996acf530020f35870',
#    'text': '"Cat people" are 11% more likely to be introverted than others.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b9e6acf530020f35871',
#    'text': 'The Egyptian Mau is the oldest breed of cat, and is the fastest pedigreed cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59b15b18d6eb960020d6767a',
#    'text': 'The place where Julius Caesar was murdered is now a cat sanctuary.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59ceab6d5c87bf0020b94e0a',
#    'text': 'The Bombay cat breed was developed to resemble a miniature panther.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59d297abc6671e0020957eb8',
#    'text': 'Cats use their whiskers to judge whether they’ll fit through a space.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026058134ec2001f032f92',
#    'text': 'For a cat at rest, the average heart rate usually is between 150 and 180 bpm, more than twice that of a human, which averages 70 bpm.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026092134ec2001f032f95',
#    'text': 'Compared to other felines, domestic cats have narrowly spaced canine teeth, adapted to their preferred prey of small rodents.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a0260d1134ec2001f032f98',
#    'text': 'Cats, like dogs, are digitigrades. They walk directly on their toes, with the bones of their feet making up the lower part of the visible leg.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038bb98e3dbc001f71978d',
#    'text': 'The domestic cat (Felis catus) is a small, typically furry, carnivorous mammal.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c178e3dbc001f71978e',
#    'text': "A cat's kidneys are so efficient, it can survive on a diet consisting only of meat, with no additional water, and can even rehydrate by drinking seawater.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c628e3dbc001f71978f',
#    'text': 'Most breeds of cat have a noted fondness for settling in high places, or perching. In the wild, a higher place may serve as a concealed site from which to hunt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038cdf8e3dbc001f719790',
#    'text': 'The ability of a cat to reflexively twist its body and balance itself during a fall is known as the "cat righting reflex".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038e188e3dbc001f719793',
#    'text': "The cat's tongue has backwards-facing spines about 500 μm long, which are called papillae. These contain keratin which makes them rigid so the papillae act like a hairbrush.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038fba8e3dbc001f719794',
#    'text': 'Among domestic cats, males are more likely to fight than females.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a12460add20f9001fb45060',
#    'text': 'The softest part of a cat is most definitely its cheek area.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a21a9fb425e43002132f045',
#    'text': 'Hank the Cat was a Maine Coon feline that was put up as a joke candidate in the 2012 United States Senate election in Virginia, a feat which gained international coverage after Hank reportedly came third behind the two major candidates, including Vice Presidential candidate Tim Kaine.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a36eb68ae877e0021ed79f3',
#    'text': "When a cat yawns, it's mouth opens so wide that you can count every tooth.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a456246255f4b0021f54c04',
#    'text': 'A cat can die from essential oils',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab252c99ee00219e11c3',
#    'text': 'Cats can move their ears 180 degrees.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab2c2c99ee00219e11c4',
#    'text': "Hearing is the strongest of cat's senses: They can hear sounds as high as 64 kHz — compared with humans, who can hear only as high as 20 kHz.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab322c99ee00219e11c5',
#    'text': 'Cats have free-floating clavicle bones that attach their shoulders to their forelimbs, which allows them to squeeze through very small spaces.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfc91b0810f0021748b92',
#    'text': 'Blackie became the richest cat in history when he inherited 15 million British Pounds.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfcd3b0810f0021748b93',
#    'text': 'Colonel Meow, a Himalayan-Persian mix who became famous on social media websites for his extremely long fur and scowling face, holds the Guinness world record for longest hair on a cat (nine inches).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfdf8b0810f0021748b94',
#    'text': 'Towser "The Mouser" of Glenturret Distillery in Crieff, Scotland, holds the Guinness World Record for the most mice caught (28,899).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75a38827521790281b99',
#    'text': 'A cat can’t climb head first down a tree because every claw on a cat’s paw points the same way. To get down from a tree, a cat must back down.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75ac8827521790281b9a',
#    'text': 'The cat who holds the record for the longest non-fatal fall is Andy. He fell from the 16th floor of an apartment building (about 200 ft/.06 km) and survived.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75e46ef087002174c284',
#    'text': 'Cats have about 130,000 hairs per square inch (20,155 hairs per square centimeter).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76106ef087002174c285',
#    'text': 'A cat’s eyesight is both better and worse than humans. It is better because cats can see in much dimmer light and they have a wider peripheral view. It’s worse because they don’t see color as well as humans do. Scientists believe grass appears red to cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76516ef087002174c287',
#    'text': 'If they have ample water, cats can tolerate temperatures up to 133 °F.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76736ef087002174c289',
#    'text': 'The lightest cat on record is a blue point Himalayan called Tinker Toy, who weighed 1 pound, 6 ounces (616 g). Tinker Toy was 2.75 inches (7 cm) tall and 7.5 inches (19 cm) long.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d767c6ef087002174c28a',
#    'text': 'Many Egyptians worshipped the goddess Bast, who had a woman’s body and a cat’s head.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76b16ef087002174c28c',
#    'text': 'The first cartoon cat was Felix the Cat in 1919. In 1940, Tom and Jerry starred in the first theatrical cartoon “Puss Gets the Boot.” In 1981 Andrew Lloyd Weber created the musical Cats, based on T.S. Eliot’s Old Possum’s Book of Practical Cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d77446ef087002174c290',
#    'text': 'Approximately 1/3 of cat owners think their pets are able to read their minds.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d776e6ef087002174c291',
#    'text': 'The claws on the cat’s back paws aren’t as sharp as the claws on the front paws because the claws in the back don’t retract and, consequently, become worn.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d78136ef087002174c292',
#    'text': 'Like humans, cats tend to favor one paw over another.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79016ef087002174c293',
#    'text': 'The most traveled cat is Hamlet, who escaped from his carrier while on a flight. He hid for seven weeks behind a panel on the airplane. By the time he was discovered, he had traveled nearly 373,000 miles (600,000 km).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79496ef087002174c294',
#    'text': 'Approximately 40,000 people are bitten by cats in the U.S. annually.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79fb6ef087002174c295',
#    'text': 'The little tufts of hair in a cat’s ear that help keep out dirt direct sounds into the ear, and insulate the ears are called "ear furnishings."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b085f85be3157001432164f',
#    'text': 'The Australian\xa0Wildlife\xa0Conservancy completed a 44km cat-proof fence in 2018 to prevent feral cats from entering the Newhaven wildlife sanctuary, who\xa0kill about a million native birds every night across Australia and have caused the extinction of 20 native species.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60baa6acf530020f35874',
#    'text': 'Black cats are bad luck in the United States, but they are good luck in the United Kingdom and Australia.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026087134ec2001f032f94',
#    'text': 'The cat skull is unusual among mammals in having very large eye sockets and a powerful and specialized jaw.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab132c99ee00219e11c2',
#    'text': 'Cats have scent glands along their tail, their forehead, lips, chin, and the underside of their front paws.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab372c99ee00219e11c6',
#    'text': 'The french tuxedo kitty, Félix, aka "Astrocat", was the first cat to go to space. She survived the trip.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b0ecc7287c6b21e6fafdf01',
#    'text': 'A male cat is called a tom.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b49110d0508220014ccfe91',
#    'text': 'Issac Newton decided to invent the cat flap because his own cat, Spithead, kept opening the door and spoiling his light experiments.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4911340508220014ccfe92',
#    'text': 'Kittens start to dream when they’re about a week old.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3fd8841d9700146158ce',
#    'text': 'Thank to an extremely efficient pair of kidneys, cats can hydrate themselves by drinking salt water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609ae8e54902001453303b',
#    'text': 'Approximately 40% of cats have a dominant paw. The rest are ambidextrous.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c3ecc2d7a200140f67eb',
#    'text': 'The average female housecat could give birth to ove 100 kittens in her lifetime.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c409c2d7a200140f67ec',
#    'text': 'Cats can have three litters a year, or approximately 12 kittens.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c422c2d7a200140f67ed',
#    'text': "Cats don't go through menopause, so they can continue to breed into their senior years.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b183fea64c2b20014b38f52',
#    'text': 'A cats whiskers are the exact width of their body.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f48841d9700146158cb',
#    'text': 'At night, Disneyland is overrun by cats. The theme park feeds them and takes care of them though, because they keep the rodent population in check.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f56841d9700146158cc',
#    'text': 'Cats lack antibodies against dog blood so they can only receive it via a transfusion once. The second time would kill them.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f6c841d9700146158cd',
#    'text': 'The Indiana State Prison allows prisoners to adopt a cat and keep it in their cell. They are meant to improve the mood of the prisoners.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4022841d9700146158d1',
#    'text': "Oftentimes shelters won't let black cats be adopted around Halloween out of a fear that they may be sacrificed.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4039841d9700146158d2',
#    'text': 'When cats bring dead animals back to their humans, they are "teaching them to hunt" as they would with a younger cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4241841d9700146158da',
#    'text': 'Cat fanciers bred and exhibited Maus in Europe until World War II, when attention toward the cat waned and it nearly went extinct.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b455f841d9700146158db',
#    'text': 'The Egyptian Mau breed was saved from extinciton when Russian princess Natalie Trubetskaya was given a Mau that was imported from the Middle East. When she emigrated to New York City in 1956, she brought along three Mau cats. She used these kitties to establish the Fatima Egyptian Mau cattery, which produced many of the ancestors of today’s Egyptian Maus in America.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4911770508220014ccfe93',
#    'text': 'Unlike kittens, adult cats don’t release any particular key hormones during sleep. They snooze all day just because they can. :)',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912650508220014ccfe98',
#    'text': "Russian scientists discovered in the 1930s that Siamese kittens kept in very warm rooms didn't develop the breed's signature dark patches.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912000508220014ccfe96',
#    'text': 'Cats have a third eyelid called a “haw”. It’s generally only visible when they’re unwell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912320508220014ccfe97',
#    'text': 'In the original Italian version of Cinderella, the benevolent fairy godmother figure was a cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '58e008450aac31001185ecfd',
#    'text': 'A cat was mayor of Talkeetna, Alaska, for 20 years. His name is Stubbs, and he died on July 23, 2017.',
#    'type': 'cat',
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551458e0b8d00148d45e3',
#    'text': 'Many people think that the Turkish Van is simply a color variation of the Turkish Angora, but in fact, they are distinct breeds that developed in different parts of Turkey.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551d48e0b8d00148d45e4',
#    'text': 'The Bengal is the result of crossbreeding between domestic cats and Asian leopard cats, and its name is derived from the scientific name for the Asian leopard cat (Felis bengalensis).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552058e0b8d00148d45e5',
#    'text': 'Despite its traditionally wild roots, the Bengal is domestic and will gladly make itself in the indoor "jungle" of your home.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552738e0b8d00148d45e6',
#    'text': "Cat's cannot see in total darkness, however their vision is much better than a human's in semidarkness because their retinas are much more sensitive to light.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c35531e8e0b8d00148d45e8',
#    'text': "If you grow your own catnip, here's how to prepare it for kitty's enjoyment: Cut several stalks of the plant from the base. Hang them upside down in a dark and dry room for several weeks. Then cut the catnip into small pieces, rub some on your cat's favorite toys or scratching post, and let the games begin!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bba466bd7ea00141eff4f',
#    'text': 'Approximately 80% of orange tabbies are male.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbab76bd7ea00141eff50',
#    'text': 'If you need to trim a cat\'s nails, choose a moment when he is relaxed. Massage his paws gently before clipping. Make sure you\'re using a pair of clippers specifically for cat\'s nails, not human nail clippers. Avoid cutting the nail too close to the "quick," the pink part of a cat\'s nail, which is full of blood vessels and nerves.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbb236bd7ea00141eff53',
#    'text': 'The gene that codes orange fur is on the X chromosome, so female cats must inherit two orange genes to end up with orange fur, while male cats only need one.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
# ...
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b2510f1c57001592f12e',
#    'type': 'cat',
#    'text': 'Courgars are the largest wild cats that can purr.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b27b0f1c57001592f12f',
#    'type': 'cat',
#    'text': 'The Norwegian Forest Cat is called "skogcatt" in its homeland of Norway and plays a role in the Norwegian fairy tales and legends.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b29f0f1c57001592f130',
#    'type': 'cat',
#    'text': 'The Abyssinian, the Siamese, and the American Shorthair were crossbred to produce the Ocicat breed.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b5b50f1c57001592f131',
#    'type': 'cat',
#    'text': 'Andy Warhol amassed quite the collection of feline friends during his lifetime, beginning with a Siamese cat named Hester that was given to him by actress Gloria Swanson. By breeding Hester with a cat named Sam, Warhol ended up with multiple litters of kittens, at one point housing 25 cats in his Upper East Side townhouse in NYC.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6090f1c57001592f132',
#    'type': 'cat',
#    'text': 'While two kittens might sound like double trouble, adopting two at a time can actually make your job easier. Two cans can keep each other company, reducing their need for socialization, and they will expend energy by playing together. Kittens in the same litter often form tight sibling bonds.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6280f1c57001592f133',
#    'type': 'cat',
#    'text': 'Some animal shelters require kittens be adopted in pairs to ensure they came from the same litter.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b64e0f1c57001592f134',
#    'type': 'cat',
#    'text': 'The Havana Brown breed hails from England, where it was created by crossbreeding Siamese cats with domestic black cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b69a0f1c57001592f135',
#    'type': 'cat',
#    'text': "While we don't know the exact origins of the Russian Blue, it's commonly believed the breed comes from the Archangel Isles in northwestern Russia—the region's cold climate would certainly explain the breed's plush coat.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6f10f1c57001592f136',
#    'type': 'cat',
#    'text': "Traveling with cats can be stressful for everyone involved. Whether you're taking a kitty to the vet, or on a road trip, or on a flight, there are things you can do to help her stay relaxed in the carrier. Pet shops sell calming treats and sprays that can reduce a cat's anxiety. It might also help to put a beloved toy or a blanket in the carrier.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b7170f1c57001592f137',
#    'type': 'cat',
#    'text': 'The wild-looking but domestic Ocicat is named for its resemblance to the ocelot, a small South American wild cat.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38bb910f1c57001592f14e',
#    'type': 'cat',
#    'text': 'Dr. Seuss wrote The Cat in the Hat using only 236 words.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d4a4fc6b6c1290015d43471',
#    'type': 'cat',
#    'text': 'Cats are the most interesting mammals on earth.',
#    'user': {'_id': '5d4a4fa4b6c1290015d43470',
#     'name': {'first': 'Yvette', 'last': 'Johnson-Rodgers'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d8a61992c54210015bf6076',
#    'type': 'cat',
#    'text': '"Cats "knead" because of seperation from their mothers".',
#    'user': {'_id': '5d70057df83a9d00155de899',
#     'name': {'first': 'Yang', 'last': 'Zhang'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9c556168a764001553b382',
#    'type': 'cat',
#    'text': 'A cat has 244 bones in its entire body—even more than a human, who only has 206 bones.',
#    'user': {'_id': '5d84ce8abf541a0015b5febb',
#     'name': {'first': 'Veronika', 'last': 'Koval'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9d4ae168a764001553b388',
#    'type': 'cat',
#    'text': 'Cats conserve energy by sleeping for an average of 13 to14 hours a day.',
#    'user': {'_id': '5d9d4a4468a764001553b387',
#     'name': {'first': 'Erick', 'last': 'Vazquez'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5db2bd49085bcb0015750662',
#    'type': 'cat',
#    'text': 'All cats are grey at night.',
#    'user': {'_id': '5db2bcbe085bcb0015750661',
#     'name': {'first': 'Владимир', 'last': 'А'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9cf25868a764001553b386',
#    'type': 'cat',
#    'text': 'XYZ.',
#    'user': {'_id': '5d9cf24e68a764001553b385',
#     'name': {'first': 'Mateusz', 'last': 'Głowacki'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daee7dbec4a6500156d2e6d',
#    'type': 'cat',
#    'text': 'Test.',
#    'user': {'_id': '5da41b7504ce7e001534bfa1',
#     'name': {'first': 'mohammed', 'last': 'aljundi'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38baf20f1c57001592f14b',
#    'type': 'cat',
#    'text': "The stationmaster of the Kishi rail station in western Japan until 2015 was a cat named Tama. The calico cat wore a stationmaster's cap and greeted visitors by the ticket gate. After her death, Tama was elevated to the status of a goddess in a Shinto-style funeral.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb440f1c57001592f14c',
#    'type': 'cat',
#    'text': "It's important for cats to have regular ear exams—this is something you can do at home! Gently fold back the ears and look into the ear canal. The inner ear should be pale pink with little to no earwax. If you notice redness, swelling, discharge, or a lot of earwax, it's time to see a veterinarian.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb7a0f1c57001592f14d',
#    'type': 'cat',
#    'text': 'In Norse mythology, the goddess Freya travels in a chariot pulled by two cats—specifically Norwegian Forest Cats.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bbb20f1c57001592f14f',
#    'type': 'cat',
#    'text': 'American Curl kittens are born with straight ears, but the ears begin to curl back after just a few days.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc0c0f1c57001592f150',
#    'type': 'cat',
#    'text': "If your cat licks from the toilet, bathtub, or sink, she may be telling you something about the water bowl. Make sure it's clean, replace the water regularly to keep it from getting stale or developing a film on top, and if necessary, get a new bowl. Some cats prefer glass bowls to plastic.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc630f1c57001592f151',
#    'type': 'cat',
#    'text': "Georgia O'Keeffe was a celebrated painter, a figurehead of American modernism, a fashion icon, and... a cat owner! O'Keeffe kept a number of animals at her home in New Mexico, including her pet Siamese cat, who appears alongside O'Keeffe in a portrait shot by photographer John Candelario.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc970f1c57001592f152',
#    'type': 'cat',
#    'text': 'The pink substance inside a cat\'s nail is called the "quick" or the "dermis". When trimming your cat\'s nails, be sure to only cut the upper white part of the nail, not the quick.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bcc00f1c57001592f153',
#    'type': 'cat',
#    'text': 'The irresistable and cuddly Ragamuffin is the result of crossbreeding Ragdoll cats with Persians, Himalayans, and other larger longhaired breeds.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd180f1c57001592f154',
#    'type': 'cat',
#    'text': 'Cats are among only a few animals that walk by moving their two right legs one after another and then their two left legs, rather than moving diagonal limbs simultaneously. Giraffes and camels also have this quality.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd750f1c57001592f155',
#    'type': 'cat',
#    'text': "Legend holds that a goddess rewarded a temple cat's piety by turning the cat's eyes blue and his coat golden, thus creating the first Birman cat.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bdab0f1c57001592f156',
#    'type': 'cat',
#    'text': "While some cats love being brushed, others don't take to it naturally. Try to groom your cat in the same spot at the same time of day to create a sense of routine.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be200f1c57001592f157',
#    'type': 'cat',
#    'text': 'The Turkish Van is often called the "swimming cat" because they are naturals in the water, thanks in part to their uniquely textured, water-resistant coat.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be370f1c57001592f158',
#    'type': 'cat',
#    'text': 'Kittens typically begin to engage in playful behavior at around four weeks of age.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d3e2191484b54001508b0df',
#    'type': 'cat',
#    'text': 'Cats can be nation president.',
#    'user': {'_id': '5d3dedfa484b54001508b0de',
#     'name': {'first': 'Jonathan', 'last': 'Velazquez'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d4878cca994550015e6ca0a',
#    'type': 'cat',
#    'text': 'Horse.',
#    'user': {'_id': '5d48783ca994550015e6ca09',
#     'name': {'first': 'Artemiy', 'last': 'Pyatakov'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d5dc687b155490015c5663f',
#    'type': 'cat',
#    'text': 'The cats are fools.',
#    'user': {'_id': '5d5dc631b155490015c5663e',
#     'name': {'first': 'Martin', 'last': 'Paredez'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d736a9617cd6300154df550',
#    'type': 'cat',
#    'text': 'A.',
#    'user': {'_id': '5d736a7817cd6300154df54f',
#     'name': {'first': 'Ade', 'last': 'Suluh'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d839adc8a86520015f44f8e',
#    'type': 'cat',
#    'text': 'Cats purr.',
#    'user': {'_id': '5d839a818a86520015f44f8d',
#     'name': {'first': 'Ju', 'last': 'Lia'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d91fc7cc586ca0015c71695',
#    'type': 'cat',
#    'text': 'GG.',
#    'user': {'_id': '5d91fc56c586ca0015c71694',
#     'name': {'first': '기웅', 'last': '김'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d94d26c6845b800156579b5',
#    'type': 'cat',
#    'text': 'Gatos.',
#    'user': {'_id': '5d94d25c6845b800156579b4',
#     'name': {'first': 'Dave', 'last': 'More'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d9bd688f98b610015c25ee2',
#    'type': 'cat',
#    'text': 'Is this a dumb app?.',
#    'user': {'_id': '5d9bd5b9f98b610015c25edf',
#     'name': {'first': 'Digggid', 'last': 'Tsar'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daa121c79186100154250be',
#    'type': 'cat',
#    'text': 'Dr. Bootsy Calico love cats, he was raised by cats. He is the main antagonist in The Boss Baby: Back in Business.',
#    'user': {'_id': '5daa103779186100154250bd',
#     'name': {'first': 'Daniel', 'last': 'Carvalho'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daa192179186100154250c4',
#    'type': 'cat',
#    'text': 'GitHub is a cloud source version control system where its mascot is an octocat, an anthropomorphized cat with five tentacles.',
#    'user': {'_id': '5daa103779186100154250bd',
#     'name': {'first': 'Daniel', 'last': 'Carvalho'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daed556ec4a6500156d2e6c',
#    'type': 'cat',
#    'text': 'One of the biggest pilgrimage sites in the middle ages was the cathedral of Caterbury.',
#    'user': {'_id': '5daec340ec4a6500156d2e6b',
#     'name': {'first': 'jo', 'last': 'ne'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5db6ac1ab5f3720015400ea4',
#    'type': 'cat',
#    'text': 'Cats have fur.',
#    'user': {'_id': '5db6ac04b5f3720015400ea3',
#     'name': {'first': 'Deekay', 'last': 'Em'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5db9577511880200157ad78a',
#    'type': 'cat',
#    'text': 'Testing bro.',
#    'user': {'_id': '5db956e711880200157ad783',
#     'name': {'first': 'Test', 'last': 'test'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5db9bf3511880200157ad78e',
#    'type': 'cat',
#    'text': 'A cat has been known to beg for food even when there already is food in its bowl.',
#    'user': {'_id': '5db9beb211880200157ad78d',
#     'name': {'first': 'Nick', 'last': 'Hyland'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dc944f5353d620015a71ce0',
#    'type': 'cat',
#    'text': "I got 3 cat and i'm allergic to them.",
#    'user': {'_id': '5dc944d7353d620015a71cdf',
#     'name': {'first': 'João', 'last': 'Guerreiro'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dd21b91a960ba0015a66895',
#    'type': 'cat',
#    'text': 'The technical term for a cat’s hairball is a “bezoar.”.',
#    'user': {'_id': '5dd21b29a960ba0015a66894',
#     'name': {'first': 'Gabriel', 'last': 'Lien'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dd3a48821bcaf0015eaa854',
#    'type': 'cat',
#    'text': 'Cats named Meowduri are cute.',
#    'user': {'_id': '5dd3a45921bcaf0015eaa851',
#     'name': {'first': 'Aaqib', 'last': 'Ismail'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dd401d08f1fb70015b894ad',
#    'type': 'cat',
#    'text': "Cat's are not dogs.",
#    'user': {'_id': '5dd401b88f1fb70015b894ac',
#     'name': {'first': 'Ronnie', 'last': 'Kilsbo'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ddd252f3e2c6c0015051ac2',
#    'type': 'cat',
#    'text': 'That cat can be the killer of mom.',
#    'user': {'_id': '5ddd14d23e2c6c0015051ac1',
#     'name': {'first': 'FATİH', 'last': 'KESER'}},
#    'upvotes': 0,
#    'userUpvoted': None}]}
